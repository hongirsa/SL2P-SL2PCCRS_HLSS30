# %%
import sys
import os,numpy
import pandas as pd

# %%
years=list(range(2014, 2024))
# category=['HW', 'MW', 'SW']
# category=['HW','SW']
# category=['mixed']
# category=['HW', 'mixed', 'SW']

category=['HW', 'SW']
for i in years:
    for j in category:        
      
        # fn1='E:/vegetation/gee/notebook/CFS/processing/updates/Landsat/HLS_FO_2007_2018_'+j+'_'+str(i)+'_LAI_updated.csv'
        # fn2='E:/vegetation/gee/notebook/CFS/processing/Landsat/HLS_FO_2007_2018_'+j+'_'+str(i)+'_LAI.csv'
        # print (fn1)
        # print (fn2)
        
        fn1='E:/vegetation/gee/notebook/CFS/HW_SW/update/sitesHLSSR_FO_2007_2018_'+j+'_'+str(i)+'_apr_nov_fraction50_ls40_LAI_SL2PV1.csv'     
        fn2='E:/vegetation/gee/notebook/CFS/HW_SW/Landsat/SR/HLS_FO_2007_2018_'+j+'_'+str(i)+'_SR_LAI_SL2PV1.csv'
        print (fn1)
        print (fn2)

        
        outputfile='E:/vegetation/gee/notebook/CFS/processing/com_v1/Landsat/HLS_FO_2007_2018_'+j+'_'+str(i)+'_LAI_merge.csv'
        print (outputfile)
        
        data1=pd.read_csv(fn1)
        data2=pd.read_csv(fn2)
        print (len(data1))
        print (len(data2))
        
        # merged = data1.merge(data2)
        # merged_df = pd.concat([df1, df2])
        merged =  pd.concat([data1,data2])
        print (len(merged))
        # print (merged.head(2))
        # merged.to_csv(outputfile, index=False)

# %%
years=list(range(2014, 2024))
# category=['HW', 'MW', 'SW']
# category=['HW','SW']
category=['mixed']
# category=['HW', 'mixed', 'SW']
# category=['HW', 'SW']
for i in years:
    for j in category:        
      
        # fn1='E:/vegetation/gee/notebook/CFS/processing/updates/Landsat/HLS_FO_2007_2018_'+j+'_'+str(i)+'_LAI_updated.csv'
        # fn2='E:/vegetation/gee/notebook/CFS/processing/Landsat/HLS_FO_2007_2014_'+j+'_'+str(i)+'_LAI.csv'
        # # fn1='E:/vegetation/gee/notebook/CFS/processing/updates/S2/S2_FO_2007_2018_'+j+'_'+str(i)+'_LAI_updated.csv'
        # fn3='E:/vegetation/gee/notebook/CFS/processing/Landsat/HLS_FO_2015_2018_'+j+'_'+str(i)+'_LAI.csv'
        # print (fn1)
        # print (fn2)
        
        fn1='E:/vegetation/gee/notebook/CFS/HW_SW/update/sitesHLSSR_FO_2007_2018_'+j+'_'+str(i)+'_apr_nov_fraction50_ls40_LAI_SL2PV1.csv'
        fn2='E:/vegetation/gee/notebook/CFS/HW_SW/Landsat/SR/HLS_FO_2007_2014_'+j+'_'+str(i)+'_SR_LAI_SL2PV1.csv'       
        fn3='E:/vegetation/gee/notebook/CFS/HW_SW/Landsat/SR/HLS_FO_2015_2018_'+j+'_'+str(i)+'_SR_LAI_SL2PV1.csv'
        print (fn1)
        print (fn2)
        print (fn3)
        
        outputfile='E:/vegetation/gee/notebook/CFS/processing/com_v1/Landsat/HLS_FO_2007_2018_'+j+'_'+str(i)+'_LAI_merge.csv'
        print (outputfile)
        
        data1=pd.read_csv(fn1)
        data2=pd.read_csv(fn2)
        data3=pd.read_csv(fn3)
        print (len(data1))
        print (len(data2))
        print (len(data3))
        
        # merged = data1.merge(data2)
        # merged_df = pd.concat([df1, df2])
        merged =  pd.concat([data1,data2,data3])
        print (len(merged))
        # print (merged.head(2))
        # merged.to_csv(outputfile, index=False)

# %%
years=list(range(2014, 2024))
# category=['HW', 'MW', 'SW']
# category=['HW','SW']
# category=['mixed']
# category=['HW', 'mixed', 'SW']
category=['HW', 'SW']
for i in years:
    for j in category:        
      
        # fn1='E:/vegetation/gee/notebook/CFS/processing/updates/Landsat/HLS_FO_2007_2018_'+j+'_'+str(i)+'_fCOVER_updated.csv'
        # fn2='E:/vegetation/gee/notebook/CFS/processing/Landsat/HLS_FO_2007_2018_'+j+'_'+str(i)+'_fCOVER.csv'
        # # print (fn1)
        # # print (fn2)
        
        fn1='E:/vegetation/gee/notebook/CFS/HW_SW/update/sitesHLSSR_FO_2007_2018_'+j+'_'+str(i)+'_apr_nov_fraction50_ls40_fCOVER_SL2PV1.csv'     
        fn2='E:/vegetation/gee/notebook/CFS/HW_SW/Landsat/SR/HLS_FO_2007_2018_'+j+'_'+str(i)+'_SR_fCOVER_SL2PV1.csv'
        print (fn1)
        print (fn2)
        
        outputfile='E:/vegetation/gee/notebook/CFS/processing/com_v1/Landsat/HLS_FO_2007_2018_'+j+'_'+str(i)+'_fCOVER_merge.csv'
        print (outputfile)
        
        data1=pd.read_csv(fn1)
        data2=pd.read_csv(fn2)
        print (len(data1))
        print (len(data2))
        
        # merged = data1.merge(data2)
        # merged_df = pd.concat([df1, df2])
        merged =  pd.concat([data1,data2])
        print (len(merged))
        # print (merged.head(2))
        # merged.to_csv(outputfile, index=False)

# %%
years=list(range(2014, 2024))
# category=['HW', 'MW', 'SW']
# category=['HW','SW']
# category=['mixed']
# category=['HW', 'mixed', 'SW']
category=['HW', 'SW']
for i in years:
    for j in category:        
      
        # fn1='E:/vegetation/gee/notebook/CFS/processing/updates/Landsat/HLS_FO_2007_2018_'+j+'_'+str(i)+'_fAPAR_updated.csv'
        # fn2='E:/vegetation/gee/notebook/CFS/processing/Landsat/HLS_FO_2007_2018_'+j+'_'+str(i)+'_fAPAR.csv'
        # # print (fn1)
        # # print (fn2)
        
        fn1='E:/vegetation/gee/notebook/CFS/HW_SW/update/sitesHLSSR_FO_2007_2018_'+j+'_'+str(i)+'_apr_nov_fraction50_ls40_fAPAR_SL2PV1.csv'     
        fn2='E:/vegetation/gee/notebook/CFS/HW_SW/Landsat/SR/HLS_FO_2007_2018_'+j+'_'+str(i)+'_SR_fAPAR_SL2PV1.csv'
        print (fn1)
        print (fn2)
        
        outputfile='E:/vegetation/gee/notebook/CFS/processing/com_v1/Landsat/HLS_FO_2007_2018_'+j+'_'+str(i)+'_fAPAR_merge.csv'
        print (outputfile)
        
        data1=pd.read_csv(fn1)
        data2=pd.read_csv(fn2)
        print (len(data1))
        print (len(data2))
        
        # merged = data1.merge(data2)
        # merged_df = pd.concat([df1, df2])
        merged =  pd.concat([data1,data2])
        print (len(merged))
        # print (merged.head(2))
        # merged.to_csv(outputfile, index=False)

# %%
years=list(range(2014, 2024))
# category=['HW', 'MW', 'SW']
# category=['HW','SW']
category=['mixed']
# category=['HW', 'mixed', 'SW']
# category=['HW', 'SW']
for i in years:
    for j in category:        
      
        # fn1='E:/vegetation/gee/notebook/CFS/processing/updates/Landsat/HLS_FO_2007_2018_'+j+'_'+str(i)+'_fCOVER_updated.csv'
#         fn2='E:/vegetation/gee/notebook/CFS/processing/Landsat/HLS_FO_2007_2014_'+j+'_'+str(i)+'_fCOVER.csv'
#         # fn1='E:/vegetation/gee/notebook/CFS/processing/updates/S2/S2_FO_2007_2018_'+j+'_'+str(i)+'_LAI_updated.csv'
#         fn3='E:/vegetation/gee/notebook/CFS/processing/Landsat/HLS_FO_2015_2018_'+j+'_'+str(i)+'_fCOVER.csv'
        # print (fn1)
        # print (fn2)
        
        fn1='E:/vegetation/gee/notebook/CFS/HW_SW/update/sitesHLSSR_FO_2007_2018_'+j+'_'+str(i)+'_apr_nov_fraction50_ls40_fCOVER_SL2PV1.csv'
        fn2='E:/vegetation/gee/notebook/CFS/HW_SW/Landsat/SR/HLS_FO_2007_2014_'+j+'_'+str(i)+'_SR_fCOVER_SL2PV1.csv'       
        fn3='E:/vegetation/gee/notebook/CFS/HW_SW/Landsat/SR/HLS_FO_2015_2018_'+j+'_'+str(i)+'_SR_fCOVER_SL2PV1.csv'
        print (fn1)
        print (fn2)
        print (fn3)
        
        outputfile='E:/vegetation/gee/notebook/CFS/processing/com_v1/Landsat/HLS_FO_2007_2018_'+j+'_'+str(i)+'_fCOVER_merge.csv'
        print (outputfile)
        
        data1=pd.read_csv(fn1)
        data2=pd.read_csv(fn2)
        data3=pd.read_csv(fn3)
        print (len(data1))
        print (len(data2))
        print (len(data3))
        
        # merged = data1.merge(data2)
        # merged_df = pd.concat([df1, df2])
        merged =  pd.concat([data1,data2,data3])
        print (len(merged))
        # print (merged.head(2))
        # merged.to_csv(outputfile, index=False)

# %%
years=list(range(2014, 2024))
# category=['HW', 'MW', 'SW']
# category=['HW','SW']
category=['mixed']
# category=['HW', 'mixed', 'SW']
# category=['HW', 'SW']
for i in years:
    for j in category:        
      
        # fn1='E:/vegetation/gee/notebook/CFS/processing/updates/Landsat/HLS_FO_2007_2018_'+j+'_'+str(i)+'_fAPAR_updated.csv'
        # fn2='E:/vegetation/gee/notebook/CFS/processing/Landsat/HLS_FO_2007_2014_'+j+'_'+str(i)+'_fAPAR.csv'
        # # fn1='E:/vegetation/gee/notebook/CFS/processing/updates/S2/S2_FO_2007_2018_'+j+'_'+str(i)+'_LAI_updated.csv'
        # fn3='E:/vegetation/gee/notebook/CFS/processing/Landsat/HLS_FO_2015_2018_'+j+'_'+str(i)+'_fAPAR.csv'
        # # print (fn1)
        # # print (fn2)
        
        fn1='E:/vegetation/gee/notebook/CFS/HW_SW/update/sitesHLSSR_FO_2007_2018_'+j+'_'+str(i)+'_apr_nov_fraction50_ls40_fAPAR_SL2PV1.csv'
        fn2='E:/vegetation/gee/notebook/CFS/HW_SW/Landsat/SR/HLS_FO_2007_2014_'+j+'_'+str(i)+'_SR_fAPAR_SL2PV1.csv'       
        fn3='E:/vegetation/gee/notebook/CFS/HW_SW/Landsat/SR/HLS_FO_2015_2018_'+j+'_'+str(i)+'_SR_fAPAR_SL2PV1.csv'
        print (fn1)
        print (fn2)
        print (fn3)
        
        outputfile='E:/vegetation/gee/notebook/CFS/processing/com_v1/Landsat/HLS_FO_2007_2018_'+j+'_'+str(i)+'_fAPAR_merge.csv'
        print (outputfile)
        
        data1=pd.read_csv(fn1)
        data2=pd.read_csv(fn2)
        data3=pd.read_csv(fn3)
        print (len(data1))
        print (len(data2))
        print (len(data3))
        
        # merged = data1.merge(data2)
        # merged_df = pd.concat([df1, df2])
        merged =  pd.concat([data1,data2,data3])
        print (len(merged))
        # print (merged.head(2))
        # merged.to_csv(outputfile, index=False)
