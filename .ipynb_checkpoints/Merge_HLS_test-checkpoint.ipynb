# %%
import sys
import os,numpy
import pandas as pd

# %%
years=list(range(2014, 2024))
# category=['HW', 'MW', 'SW']
# category=['HW','SW']
# category=['mixed']
# category=['HW', 'mixed', 'SW']
category=['HW', 'SW']
for i in years:
    for j in category:        
      
        fn1='E:/vegetation/gee/notebook/CFS/processing/updates/Landsat/HLS_FO_2007_2018_'+j+'_'+str(i)+'_LAI_updated.csv'
        fn2='E:/vegetation/gee/notebook/CFS/processing/Landsat/HLS_FO_2007_2018_'+j+'_'+str(i)+'_LAI.csv'
        # print (fn1)
        # print (fn2)
        
        outputfile='E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_'+j+'_'+str(i)+'_LAI_merge.csv'
        print (outputfile)
        
        data1=pd.read_csv(fn1)
        data2=pd.read_csv(fn2)
        print (len(data1))
        print (len(data2))
        
        # merged = data1.merge(data2)
        # merged_df = pd.concat([df1, df2])
        merged =  pd.concat([data1,data2])
        print (len(merged))
        # print (merged.head(2))
        merged.to_csv(outputfile, index=False)
# Out:
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_HW_2014_LAI_merge.csv
# 1242
# 5157
# 6399
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_SW_2014_LAI_merge.csv
# 32921
# 108721
# 141642
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_HW_2015_LAI_merge.csv
# 1228
# 4726
# 5954
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_SW_2015_LAI_merge.csv
# 40261
# 130401
# 170662
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_HW_2016_LAI_merge.csv
# 1416
# 4666
# 6082
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_SW_2016_LAI_merge.csv
# 49708
# 144922
# 194630
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_HW_2017_LAI_merge.csv
# 847
# 2975
# 3822
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_SW_2017_LAI_merge.csv
# 33606
# 77353
# 110959
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_HW_2018_LAI_merge.csv
# 924
# 3671
# 4595
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_SW_2018_LAI_merge.csv
# 47834
# 123630
# 171464
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_HW_2019_LAI_merge.csv
# 1017
# 4226
# 5243
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_SW_2019_LAI_merge.csv
# 48697
# 143832
# 192529
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_HW_2020_LAI_merge.csv
# 1192
# 5133
# 6325
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_SW_2020_LAI_merge.csv
# 42999
# 128565
# 171564
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_HW_2021_LAI_merge.csv
# 1176
# 5133
# 6309
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_SW_2021_LAI_merge.csv
# 46400
# 125402
# 171802
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_HW_2022_LAI_merge.csv
# 2344
# 9237
# 11581
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_SW_2022_LAI_merge.csv
# 87606
# 247069
# 334675
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_HW_2023_LAI_merge.csv
# 1976
# 7356
# 9332
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_SW_2023_LAI_merge.csv
# 95331
# 254515
# 349846

# %%
years=list(range(2014, 2024))
# category=['HW', 'MW', 'SW']
# category=['HW','SW']
category=['mixed']
# category=['HW', 'mixed', 'SW']
# category=['HW', 'SW']
for i in years:
    for j in category:        
      
        fn1='E:/vegetation/gee/notebook/CFS/processing/updates/Landsat/HLS_FO_2007_2018_'+j+'_'+str(i)+'_LAI_updated.csv'
        fn2='E:/vegetation/gee/notebook/CFS/processing/Landsat/HLS_FO_2007_2014_'+j+'_'+str(i)+'_LAI.csv'
        # fn1='E:/vegetation/gee/notebook/CFS/processing/updates/S2/S2_FO_2007_2018_'+j+'_'+str(i)+'_LAI_updated.csv'
        fn3='E:/vegetation/gee/notebook/CFS/processing/Landsat/HLS_FO_2015_2018_'+j+'_'+str(i)+'_LAI.csv'
        # print (fn1)
        # print (fn2)
        
        outputfile='E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_'+j+'_'+str(i)+'_LAI_merge.csv'
        print (outputfile)
        
        data1=pd.read_csv(fn1)
        data2=pd.read_csv(fn2)
        data3=pd.read_csv(fn3)
        print (len(data1))
        print (len(data2))
        print (len(data3))
        
        # merged = data1.merge(data2)
        # merged_df = pd.concat([df1, df2])
        merged =  pd.concat([data1,data2,data3])
        print (len(merged))
        # print (merged.head(2))
        merged.to_csv(outputfile, index=False)
# Out:
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_mixed_2014_LAI_merge.csv
# 45871
# 118701
# 53291
# 217863
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_mixed_2015_LAI_merge.csv
# 55940
# 144200
# 61741
# 261881
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_mixed_2016_LAI_merge.csv
# 61603
# 150342
# 66964
# 278909
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_mixed_2017_LAI_merge.csv
# 40195
# 87315
# 40908
# 168418
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_mixed_2018_LAI_merge.csv
# 43858
# 110040
# 45992
# 199890
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_mixed_2019_LAI_merge.csv
# 56194
# 141922
# 60070
# 258186
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_mixed_2020_LAI_merge.csv
# 51958
# 133973
# 59846
# 245777
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_mixed_2021_LAI_merge.csv
# 55302
# 131717
# 58772
# 245791
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_mixed_2022_LAI_merge.csv
# 93666
# 242834
# 102473
# 438973
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_mixed_2023_LAI_merge.csv
# 98806
# 244659
# 105586
# 449051

# %%
years=list(range(2014, 2024))
# category=['HW', 'MW', 'SW']
# category=['HW','SW']
# category=['mixed']
# category=['HW', 'mixed', 'SW']
category=['HW', 'SW']
for i in years:
    for j in category:        
      
        fn1='E:/vegetation/gee/notebook/CFS/processing/updates/Landsat/HLS_FO_2007_2018_'+j+'_'+str(i)+'_fCOVER_updated.csv'
        fn2='E:/vegetation/gee/notebook/CFS/processing/Landsat/HLS_FO_2007_2018_'+j+'_'+str(i)+'_fCOVER.csv'
        # print (fn1)
        # print (fn2)
        
        outputfile='E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_'+j+'_'+str(i)+'_fCOVER_merge.csv'
        print (outputfile)
        
        data1=pd.read_csv(fn1)
        data2=pd.read_csv(fn2)
        print (len(data1))
        print (len(data2))
        
        # merged = data1.merge(data2)
        # merged_df = pd.concat([df1, df2])
        merged =  pd.concat([data1,data2])
        print (len(merged))
        # print (merged.head(2))
        merged.to_csv(outputfile, index=False)
# Out:
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_HW_2014_fCOVER_merge.csv
# 1242
# 5157
# 6399
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_SW_2014_fCOVER_merge.csv
# 32921
# 108721
# 141642
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_HW_2015_fCOVER_merge.csv
# 1228
# 4726
# 5954
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_SW_2015_fCOVER_merge.csv
# 40261
# 130401
# 170662
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_HW_2016_fCOVER_merge.csv
# 1416
# 4666
# 6082
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_SW_2016_fCOVER_merge.csv
# 49708
# 144922
# 194630
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_HW_2017_fCOVER_merge.csv
# 847
# 2975
# 3822
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_SW_2017_fCOVER_merge.csv
# 33606
# 77353
# 110959
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_HW_2018_fCOVER_merge.csv
# 924
# 3671
# 4595
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_SW_2018_fCOVER_merge.csv
# 47834
# 123630
# 171464
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_HW_2019_fCOVER_merge.csv
# 1017
# 4226
# 5243
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_SW_2019_fCOVER_merge.csv
# 48697
# 143832
# 192529
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_HW_2020_fCOVER_merge.csv
# 1192
# 5133
# 6325
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_SW_2020_fCOVER_merge.csv
# 42999
# 128565
# 171564
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_HW_2021_fCOVER_merge.csv
# 1176
# 5133
# 6309
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_SW_2021_fCOVER_merge.csv
# 46400
# 125402
# 171802
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_HW_2022_fCOVER_merge.csv
# 2344
# 9237
# 11581
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_SW_2022_fCOVER_merge.csv
# 87606
# 247069
# 334675
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_HW_2023_fCOVER_merge.csv
# 1976
# 7356
# 9332
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_SW_2023_fCOVER_merge.csv
# 95331
# 254515
# 349846

# %%
years=list(range(2014, 2024))
# category=['HW', 'MW', 'SW']
# category=['HW','SW']
# category=['mixed']
# category=['HW', 'mixed', 'SW']
category=['HW', 'SW']
for i in years:
    for j in category:        
      
        fn1='E:/vegetation/gee/notebook/CFS/processing/updates/Landsat/HLS_FO_2007_2018_'+j+'_'+str(i)+'_fAPAR_updated.csv'
        fn2='E:/vegetation/gee/notebook/CFS/processing/Landsat/HLS_FO_2007_2018_'+j+'_'+str(i)+'_fAPAR.csv'
        # print (fn1)
        # print (fn2)
        
        outputfile='E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_'+j+'_'+str(i)+'_fAPAR_merge.csv'
        print (outputfile)
        
        data1=pd.read_csv(fn1)
        data2=pd.read_csv(fn2)
        print (len(data1))
        print (len(data2))
        
        # merged = data1.merge(data2)
        # merged_df = pd.concat([df1, df2])
        merged =  pd.concat([data1,data2])
        print (len(merged))
        # print (merged.head(2))
        merged.to_csv(outputfile, index=False)
# Out:
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_HW_2014_fAPAR_merge.csv
# 1242
# 5157
# 6399
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_SW_2014_fAPAR_merge.csv
# 32921
# 108721
# 141642
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_HW_2015_fAPAR_merge.csv
# 1228
# 4726
# 5954
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_SW_2015_fAPAR_merge.csv
# 40261
# 130401
# 170662
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_HW_2016_fAPAR_merge.csv
# 1416
# 4666
# 6082
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_SW_2016_fAPAR_merge.csv
# 49708
# 144922
# 194630
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_HW_2017_fAPAR_merge.csv
# 847
# 2975
# 3822
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_SW_2017_fAPAR_merge.csv
# 33606
# 77353
# 110959
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_HW_2018_fAPAR_merge.csv
# 924
# 3671
# 4595
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_SW_2018_fAPAR_merge.csv
# 47834
# 123630
# 171464
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_HW_2019_fAPAR_merge.csv
# 1017
# 4226
# 5243
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_SW_2019_fAPAR_merge.csv
# 48697
# 143832
# 192529
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_HW_2020_fAPAR_merge.csv
# 1192
# 5133
# 6325
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_SW_2020_fAPAR_merge.csv
# 42999
# 128565
# 171564
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_HW_2021_fAPAR_merge.csv
# 1176
# 5133
# 6309
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_SW_2021_fAPAR_merge.csv
# 46400
# 125402
# 171802
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_HW_2022_fAPAR_merge.csv
# 2344
# 9237
# 11581
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_SW_2022_fAPAR_merge.csv
# 87606
# 247069
# 334675
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_HW_2023_fAPAR_merge.csv
# 1976
# 7356
# 9332
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_SW_2023_fAPAR_merge.csv
# 95331
# 254515
# 349846

# %%
years=list(range(2014, 2024))
# category=['HW', 'MW', 'SW']
# category=['HW','SW']
category=['mixed']
# category=['HW', 'mixed', 'SW']
# category=['HW', 'SW']
for i in years:
    for j in category:        
      
        fn1='E:/vegetation/gee/notebook/CFS/processing/updates/Landsat/HLS_FO_2007_2018_'+j+'_'+str(i)+'_fCOVER_updated.csv'
        fn2='E:/vegetation/gee/notebook/CFS/processing/Landsat/HLS_FO_2007_2014_'+j+'_'+str(i)+'_fCOVER.csv'
        # fn1='E:/vegetation/gee/notebook/CFS/processing/updates/S2/S2_FO_2007_2018_'+j+'_'+str(i)+'_LAI_updated.csv'
        fn3='E:/vegetation/gee/notebook/CFS/processing/Landsat/HLS_FO_2015_2018_'+j+'_'+str(i)+'_fCOVER.csv'
        # print (fn1)
        # print (fn2)
        
        outputfile='E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_'+j+'_'+str(i)+'_fCOVER_merge.csv'
        print (outputfile)
        
        data1=pd.read_csv(fn1)
        data2=pd.read_csv(fn2)
        data3=pd.read_csv(fn3)
        print (len(data1))
        print (len(data2))
        print (len(data3))
        
        # merged = data1.merge(data2)
        # merged_df = pd.concat([df1, df2])
        merged =  pd.concat([data1,data2,data3])
        print (len(merged))
        # print (merged.head(2))
        merged.to_csv(outputfile, index=False)
# Out:
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_mixed_2014_fCOVER_merge.csv
# 45871
# 118701
# 53291
# 217863
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_mixed_2015_fCOVER_merge.csv
# 55940
# 144200
# 61741
# 261881
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_mixed_2016_fCOVER_merge.csv
# 61603
# 150342
# 66964
# 278909
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_mixed_2017_fCOVER_merge.csv
# 40195
# 87315
# 40908
# 168418
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_mixed_2018_fCOVER_merge.csv
# 43858
# 110040
# 45992
# 199890
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_mixed_2019_fCOVER_merge.csv
# 56194
# 141922
# 60070
# 258186
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_mixed_2020_fCOVER_merge.csv
# 51958
# 133973
# 59846
# 245777
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_mixed_2021_fCOVER_merge.csv
# 55302
# 131717
# 58772
# 245791
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_mixed_2022_fCOVER_merge.csv
# 93666
# 242834
# 102473
# 438973
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_mixed_2023_fCOVER_merge.csv
# 98806
# 244659
# 105586
# 449051

# %%
years=list(range(2014, 2024))
# category=['HW', 'MW', 'SW']
# category=['HW','SW']
category=['mixed']
# category=['HW', 'mixed', 'SW']
# category=['HW', 'SW']
for i in years:
    for j in category:        
      
        fn1='E:/vegetation/gee/notebook/CFS/processing/updates/Landsat/HLS_FO_2007_2018_'+j+'_'+str(i)+'_fAPAR_updated.csv'
        fn2='E:/vegetation/gee/notebook/CFS/processing/Landsat/HLS_FO_2007_2014_'+j+'_'+str(i)+'_fAPAR.csv'
        # fn1='E:/vegetation/gee/notebook/CFS/processing/updates/S2/S2_FO_2007_2018_'+j+'_'+str(i)+'_LAI_updated.csv'
        fn3='E:/vegetation/gee/notebook/CFS/processing/Landsat/HLS_FO_2015_2018_'+j+'_'+str(i)+'_fAPAR.csv'
        # print (fn1)
        # print (fn2)
        
        outputfile='E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_'+j+'_'+str(i)+'_fAPAR_merge.csv'
        print (outputfile)
        
        data1=pd.read_csv(fn1)
        data2=pd.read_csv(fn2)
        data3=pd.read_csv(fn3)
        print (len(data1))
        print (len(data2))
        print (len(data3))
        
        # merged = data1.merge(data2)
        # merged_df = pd.concat([df1, df2])
        merged =  pd.concat([data1,data2,data3])
        print (len(merged))
        # print (merged.head(2))
        merged.to_csv(outputfile, index=False)
# Out:
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_mixed_2014_fAPAR_merge.csv
# 45871
# 118701
# 53291
# 217863
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_mixed_2015_fAPAR_merge.csv
# 55940
# 144200
# 61741
# 261881
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_mixed_2016_fAPAR_merge.csv
# 61603
# 150342
# 66964
# 278909
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_mixed_2017_fAPAR_merge.csv
# 40195
# 87315
# 40908
# 168418
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_mixed_2018_fAPAR_merge.csv
# 43858
# 110040
# 45992
# 199890
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_mixed_2019_fAPAR_merge.csv
# 56194
# 141922
# 60070
# 258186
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_mixed_2020_fAPAR_merge.csv
# 51958
# 133973
# 59846
# 245777
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_mixed_2021_fAPAR_merge.csv
# 55302
# 131717
# 58772
# 245791
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_mixed_2022_fAPAR_merge.csv
# 93666
# 242834
# 102473
# 438973
# E:/vegetation/gee/notebook/CFS/processing/com/Landsat/HLS_FO_2007_2018_mixed_2023_fAPAR_merge.csv
# 98806
# 244659
# 105586
# 449051
