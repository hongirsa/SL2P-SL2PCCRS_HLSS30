# %%
import sys
import os,numpy
import pandas as pd

# %%
years=list(range(2019, 2024))
# category=['HW', 'MW', 'SW']
# category=['HW','SW']
# category=['mixed']
# category=['HW', 'mixed', 'SW']
category=['HW', 'SW']
for i in years:
    for j in category:        
      
        fn1='E:/vegetation/gee/notebook/CFS/processing/updates/S2/S2_FO_2007_2018_'+j+'_'+str(i)+'_LAI_updated.csv'
        fn2='E:/vegetation/gee/notebook/CFS/processing/S2/S2_FO_2007_2018_'+j+'_'+str(i)+'_LAI.csv'
        # print (fn1)
        # print (fn2)
        
        outputfile='E:/vegetation/gee/notebook/CFS/processing/com/S2/S2_FO_2007_2018_'+j+'_'+str(i)+'_LAI_merge.csv'
        print (outputfile)
        
        data1=pd.read_csv(fn1)
        data2=pd.read_csv(fn2)
        print (len(data1))
        print (len(data2))
        
        # merged = data1.merge(data2)
        # merged_df = pd.concat([df1, df2])
        merged =  pd.concat([data1,data2])
        print (len(merged))
        # print (merged.head(2))
        merged.to_csv(outputfile, index=False)
# Out:
# E:/vegetation/gee/notebook/CFS/processing/com/S2/S2_FO_2007_2018_HW_2019_LAI_merge.csv
# 5204
# 23736
# 28940
# E:/vegetation/gee/notebook/CFS/processing/com/S2/S2_FO_2007_2018_SW_2019_LAI_merge.csv
# 346765
# 1065192
# 1411957
# E:/vegetation/gee/notebook/CFS/processing/com/S2/S2_FO_2007_2018_HW_2020_LAI_merge.csv
# 7807
# 30426
# 38233
# E:/vegetation/gee/notebook/CFS/processing/com/S2/S2_FO_2007_2018_SW_2020_LAI_merge.csv
# 383926
# 1206618
# 1590544
# E:/vegetation/gee/notebook/CFS/processing/com/S2/S2_FO_2007_2018_HW_2021_LAI_merge.csv
# 5728
# 24290
# 30018
# E:/vegetation/gee/notebook/CFS/processing/com/S2/S2_FO_2007_2018_SW_2021_LAI_merge.csv
# 305985
# 997867
# 1303852
# E:/vegetation/gee/notebook/CFS/processing/com/S2/S2_FO_2007_2018_HW_2022_LAI_merge.csv
# 5897
# 27045
# 32942
# E:/vegetation/gee/notebook/CFS/processing/com/S2/S2_FO_2007_2018_SW_2022_LAI_merge.csv
# 382809
# 1092694
# 1475503
# ...

# %%
years=list(range(2019, 2024))
# category=['HW', 'MW', 'SW']
# category=['HW','SW']
category=['mixed']
# category=['HW', 'mixed', 'SW']
# category=['HW', 'SW']
for i in years:
    for j in category:        
      
        fn1='E:/vegetation/gee/notebook/CFS/processing/updates/S2/S2_FO_2007_2018_'+j+'_'+str(i)+'_LAI_updated.csv'
        fn2='E:/vegetation/gee/notebook/CFS/processing/S2/S2_FO_2007_2014_'+j+'_'+str(i)+'_LAI.csv'
        # fn1='E:/vegetation/gee/notebook/CFS/processing/updates/S2/S2_FO_2007_2018_'+j+'_'+str(i)+'_LAI_updated.csv'
        fn3='E:/vegetation/gee/notebook/CFS/processing/S2/S2_FO_2015_2018_'+j+'_'+str(i)+'_LAI.csv'
        # print (fn1)
        # print (fn2)
        
        outputfile='E:/vegetation/gee/notebook/CFS/processing/com/S2/S2_FO_2007_2018_'+j+'_'+str(i)+'_LAI_merge.csv'
        print (outputfile)
        
        data1=pd.read_csv(fn1)
        data2=pd.read_csv(fn2)
        data3=pd.read_csv(fn3)
        print (len(data1))
        print (len(data2))
        print (len(data3))
        
        # merged = data1.merge(data2)
        # merged_df = pd.concat([df1, df2])
        merged =  pd.concat([data1,data2,data3])
        print (len(merged))
        # print (merged.head(2))
        merged.to_csv(outputfile, index=False)
# Out:
# E:/vegetation/gee/notebook/CFS/processing/com/S2/S2_FO_2007_2018_mixed_2019_LAI_merge.csv
# 431456
# 1058124
# 444548
# 1934128
# E:/vegetation/gee/notebook/CFS/processing/com/S2/S2_FO_2007_2018_mixed_2020_LAI_merge.csv
# 514916
# 1280888
# 536419
# 2332223
# E:/vegetation/gee/notebook/CFS/processing/com/S2/S2_FO_2007_2018_mixed_2021_LAI_merge.csv
# 421972
# 1064649
# 447584
# 1934205
# E:/vegetation/gee/notebook/CFS/processing/com/S2/S2_FO_2007_2018_mixed_2022_LAI_merge.csv
# 431050
# 1078109
# 453590
# 1962749
# E:/vegetation/gee/notebook/CFS/processing/com/S2/S2_FO_2007_2018_mixed_2023_LAI_merge.csv
# 443964
# 1103315
# 464901
# 2012180

# %%
years=list(range(2019, 2024))
# category=['HW', 'MW', 'SW']
# category=['HW','SW']
# category=['mixed']
# category=['HW', 'mixed', 'SW']
category=['HW', 'SW']
for i in years:
    for j in category:        
      
        fn1='E:/vegetation/gee/notebook/CFS/processing/updates/S2/S2_FO_2007_2018_'+j+'_'+str(i)+'_fCOVER_updated.csv'
        fn2='E:/vegetation/gee/notebook/CFS/processing/S2/S2_FO_2007_2018_'+j+'_'+str(i)+'_fCOVER.csv'
        # print (fn1)
        # print (fn2)
        
        outputfile='E:/vegetation/gee/notebook/CFS/processing/com/S2/S2_FO_2007_2018_'+j+'_'+str(i)+'_fCOVER_merge.csv'
        print (outputfile)
        
        data1=pd.read_csv(fn1)
        data2=pd.read_csv(fn2)
        print (len(data1))
        print (len(data2))
        
        # merged = data1.merge(data2)
        # merged_df = pd.concat([df1, df2])
        merged =  pd.concat([data1,data2])
        print (len(merged))
        # print (merged.head(2))
        merged.to_csv(outputfile, index=False)
# Out:
# E:/vegetation/gee/notebook/CFS/processing/com/S2/S2_FO_2007_2018_HW_2019_fCOVER_merge.csv
# 5204
# 23736
# 28940
# E:/vegetation/gee/notebook/CFS/processing/com/S2/S2_FO_2007_2018_SW_2019_fCOVER_merge.csv
# 346765
# 1065192
# 1411957
# E:/vegetation/gee/notebook/CFS/processing/com/S2/S2_FO_2007_2018_HW_2020_fCOVER_merge.csv
# 7807
# 30426
# 38233
# E:/vegetation/gee/notebook/CFS/processing/com/S2/S2_FO_2007_2018_SW_2020_fCOVER_merge.csv
# 383926
# 1206618
# 1590544
# E:/vegetation/gee/notebook/CFS/processing/com/S2/S2_FO_2007_2018_HW_2021_fCOVER_merge.csv
# 5728
# 24290
# 30018
# E:/vegetation/gee/notebook/CFS/processing/com/S2/S2_FO_2007_2018_SW_2021_fCOVER_merge.csv
# 305985
# 997867
# 1303852
# E:/vegetation/gee/notebook/CFS/processing/com/S2/S2_FO_2007_2018_HW_2022_fCOVER_merge.csv
# 5897
# 27045
# 32942
# E:/vegetation/gee/notebook/CFS/processing/com/S2/S2_FO_2007_2018_SW_2022_fCOVER_merge.csv
# 382809
# 1092694
# 1475503
# ...

# %%
years=list(range(2019, 2024))
# category=['HW', 'MW', 'SW']
# category=['HW','SW']
# category=['mixed']
# category=['HW', 'mixed', 'SW']
category=['HW', 'SW']
for i in years:
    for j in category:        
      
        fn1='E:/vegetation/gee/notebook/CFS/processing/updates/S2/S2_FO_2007_2018_'+j+'_'+str(i)+'_fAPAR_updated.csv'
        fn2='E:/vegetation/gee/notebook/CFS/processing/S2/S2_FO_2007_2018_'+j+'_'+str(i)+'_fAPAR.csv'
        # print (fn1)
        # print (fn2)
        
        outputfile='E:/vegetation/gee/notebook/CFS/processing/com/S2/S2_FO_2007_2018_'+j+'_'+str(i)+'_fAPAR_merge.csv'
        print (outputfile)
        
        data1=pd.read_csv(fn1)
        data2=pd.read_csv(fn2)
        print (len(data1))
        print (len(data2))
        
        # merged = data1.merge(data2)
        # merged_df = pd.concat([df1, df2])
        merged =  pd.concat([data1,data2])
        print (len(merged))
        # print (merged.head(2))
        merged.to_csv(outputfile, index=False)
# Out:
# E:/vegetation/gee/notebook/CFS/processing/com/S2/S2_FO_2007_2018_HW_2019_fAPAR_merge.csv
# 5204
# 23736
# 28940
# E:/vegetation/gee/notebook/CFS/processing/com/S2/S2_FO_2007_2018_SW_2019_fAPAR_merge.csv
# 346765
# 1065192
# 1411957
# E:/vegetation/gee/notebook/CFS/processing/com/S2/S2_FO_2007_2018_HW_2020_fAPAR_merge.csv
# 7807
# 30426
# 38233
# E:/vegetation/gee/notebook/CFS/processing/com/S2/S2_FO_2007_2018_SW_2020_fAPAR_merge.csv
# 383926
# 1206618
# 1590544
# E:/vegetation/gee/notebook/CFS/processing/com/S2/S2_FO_2007_2018_HW_2021_fAPAR_merge.csv
# 5728
# 24290
# 30018
# E:/vegetation/gee/notebook/CFS/processing/com/S2/S2_FO_2007_2018_SW_2021_fAPAR_merge.csv
# 305985
# 997867
# 1303852
# E:/vegetation/gee/notebook/CFS/processing/com/S2/S2_FO_2007_2018_HW_2022_fAPAR_merge.csv
# 5897
# 27045
# 32942
# E:/vegetation/gee/notebook/CFS/processing/com/S2/S2_FO_2007_2018_SW_2022_fAPAR_merge.csv
# 382809
# 1092694
# 1475503
# ...

# %%
years=list(range(2019, 2024))
# category=['HW', 'MW', 'SW']
# category=['HW','SW']
category=['mixed']
# category=['HW', 'mixed', 'SW']
# category=['HW', 'SW']
for i in years:
    for j in category:        
      
        fn1='E:/vegetation/gee/notebook/CFS/processing/updates/S2/S2_FO_2007_2018_'+j+'_'+str(i)+'_fCOVER_updated.csv'
        fn2='E:/vegetation/gee/notebook/CFS/processing/S2/S2_FO_2007_2014_'+j+'_'+str(i)+'_fCOVER.csv'
        # fn1='E:/vegetation/gee/notebook/CFS/processing/updates/S2/S2_FO_2007_2018_'+j+'_'+str(i)+'_LAI_updated.csv'
        fn3='E:/vegetation/gee/notebook/CFS/processing/S2/S2_FO_2015_2018_'+j+'_'+str(i)+'_fCOVER.csv'
        # print (fn1)
        # print (fn2)
        
        outputfile='E:/vegetation/gee/notebook/CFS/processing/com/S2/S2_FO_2007_2018_'+j+'_'+str(i)+'_fCOVER_merge.csv'
        print (outputfile)
        
        data1=pd.read_csv(fn1)
        data2=pd.read_csv(fn2)
        data3=pd.read_csv(fn3)
        print (len(data1))
        print (len(data2))
        print (len(data3))
        
        # merged = data1.merge(data2)
        # merged_df = pd.concat([df1, df2])
        merged =  pd.concat([data1,data2,data3])
        print (len(merged))
        # print (merged.head(2))
        merged.to_csv(outputfile, index=False)
# Out:
# E:/vegetation/gee/notebook/CFS/processing/com/S2/S2_FO_2007_2018_mixed_2019_fCOVER_merge.csv
# 431456
# 1058124
# 444548
# 1934128
# E:/vegetation/gee/notebook/CFS/processing/com/S2/S2_FO_2007_2018_mixed_2020_fCOVER_merge.csv
# 514916
# 1280888
# 536419
# 2332223
# E:/vegetation/gee/notebook/CFS/processing/com/S2/S2_FO_2007_2018_mixed_2021_fCOVER_merge.csv
# 421972
# 1064649
# 447584
# 1934205
# E:/vegetation/gee/notebook/CFS/processing/com/S2/S2_FO_2007_2018_mixed_2022_fCOVER_merge.csv
# 431050
# 1078109
# 453590
# 1962749
# E:/vegetation/gee/notebook/CFS/processing/com/S2/S2_FO_2007_2018_mixed_2023_fCOVER_merge.csv
# 443964
# 1103315
# 464901
# 2012180

# %%
years=list(range(2019, 2024))
# category=['HW', 'MW', 'SW']
# category=['HW','SW']
category=['mixed']
# category=['HW', 'mixed', 'SW']
# category=['HW', 'SW']
for i in years:
    for j in category:        
      
        fn1='E:/vegetation/gee/notebook/CFS/processing/updates/S2/S2_FO_2007_2018_'+j+'_'+str(i)+'_fAPAR_updated.csv'
        fn2='E:/vegetation/gee/notebook/CFS/processing/S2/S2_FO_2007_2014_'+j+'_'+str(i)+'_fAPAR.csv'
        # fn1='E:/vegetation/gee/notebook/CFS/processing/updates/S2/S2_FO_2007_2018_'+j+'_'+str(i)+'_LAI_updated.csv'
        fn3='E:/vegetation/gee/notebook/CFS/processing/S2/S2_FO_2015_2018_'+j+'_'+str(i)+'_fAPAR.csv'
        # print (fn1)
        # print (fn2)
        
        outputfile='E:/vegetation/gee/notebook/CFS/processing/com/S2/S2_FO_2007_2018_'+j+'_'+str(i)+'_fAPAR_merge.csv'
        print (outputfile)
        
        data1=pd.read_csv(fn1)
        data2=pd.read_csv(fn2)
        data3=pd.read_csv(fn3)
        print (len(data1))
        print (len(data2))
        print (len(data3))
        
        # merged = data1.merge(data2)
        # merged_df = pd.concat([df1, df2])
        merged =  pd.concat([data1,data2,data3])
        print (len(merged))
        # print (merged.head(2))
        merged.to_csv(outputfile, index=False)
# Out:
# E:/vegetation/gee/notebook/CFS/processing/com/S2/S2_FO_2007_2018_mixed_2019_fAPAR_merge.csv
# 431456
# 1058124
# 444548
# 1934128
# E:/vegetation/gee/notebook/CFS/processing/com/S2/S2_FO_2007_2018_mixed_2020_fAPAR_merge.csv
# 514916
# 1280888
# 536419
# 2332223
# E:/vegetation/gee/notebook/CFS/processing/com/S2/S2_FO_2007_2018_mixed_2021_fAPAR_merge.csv
# 421972
# 1064649
# 447584
# 1934205
# E:/vegetation/gee/notebook/CFS/processing/com/S2/S2_FO_2007_2018_mixed_2022_fAPAR_merge.csv
# 431050
# 1078109
# 453590
# 1962749
# E:/vegetation/gee/notebook/CFS/processing/com/S2/S2_FO_2007_2018_mixed_2023_fAPAR_merge.csv
# 443964
# 1103315
# 464901
# 2012180
